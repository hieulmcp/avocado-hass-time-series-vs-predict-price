# %% [markdown]
# # Câu 2: Thực hiện dự đoán giá, khả năng mở rộng trong tương lai với Organic Avocado ở vùng California

# %% [markdown]
# ## A. Import thư viện

# %%
# 1. Import library
import lib.step1ml_utilis_summaryPre_processing as pre
import lib.step2ml_utils_feature_selection as fea
import lib.step3ml_utils_model_design_testing_regression as reg
import lib.step4ml_utils_model_design_testing_explainability as exp
import lib.step5ml_utils_model_design_testing_visualize_models as vis
import lib.step6ml_utils_model_design_testing_geospatial_analysis as geo
import lib.step9ml_Text_Kmeans_Clustering as clu
import lib.step11ml_utilis_model_design_time_series as clu
import matplotlib
import matplotlib_inline
# %matplotlib inline


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # B. Model

# %% [markdown]
# ### 1.0. Upload dữ liệu

# %%
import pandas as pd
dir_file = "data/avocado_model.csv"
df = pd.read_csv(dir_file)
df.head()
# Out:
#    Unnamed: 0    fea_date  fea_average_price  fea_total_Volume  fea_item_4046  \
# 0           1  2015-12-27               1.33          64236.62        1036.74
# 1           2  2015-12-20               1.35          54876.98         674.28
# 2           3  2015-12-13               0.93         118220.22         794.70
# 3           4  2015-12-06               1.08          78992.15        1132.00
# 4           5  2015-11-29               1.28          51039.60         941.48
#
#    fea_item_4225  fea_item_4770  fea_total_Bags  fea_small_bags  \
# 0       54454.85          48.16         8696.87         8603.62
# 1       44638.81          58.33         9505.56         9408.07
# 2      109149.67         130.50         8145.35         8042.21
# 3       71976.41          72.58         5811.16         5677.40
# 4       43838.39          75.78         6183.95         5986.26
#
#    fea_large_bags  ...  Item_4046  Item_4225  Item_4770  Total_Bags  \
# 0           93.25  ...    1036.74   54454.85      48.16     8696.87
# 1           97.49  ...     674.28   44638.81      58.33     9505.56
# 2          103.14  ...     794.70  109149.67     130.50     8145.35
# 3          133.76  ...    1132.00   71976.41      72.58     5811.16
# 4          197.69  ...     941.48   43838.39      75.78     6183.95
#
#    Small_Bags  Large_Bags  XLarge_Bags          type  year  region
# 0     8603.62       93.25         0.00  conventional  2015  Albany
# 1     9408.07       97.49         0.00  conventional  2015  Albany
# 2     8042.21      103.14         0.00  conventional  2015  Albany
# 3     5677.40      133.76         0.00  conventional  2015  Albany
# 4     5986.26      197.69         0.00  conventional  2015  Albany
#
# [5 rows x 95 columns]

# %%
# Lọc dữ liệu organic
feature_name = 'type'
name_type = 'organic'
data_organic = pre.filter_dataframe(df=df, feature_name=feature_name, name_type=name_type)
# Out:
# close

# %%
# Lọc dữ liệu bang California
name_type = 'California'
feature_name = 'region'
data_california = pre.filter_dataframe(df=data_organic, feature_name=feature_name, name_type=name_type)
# Out:
# close

# %% [markdown]
# ### 1.1. Chọn lst_k_best

# %%
lst_k_best_option1 = ['fea_average_price','fea_type_organic', 'fea_large_bags', 'fea_item_4046', 'fea_year_', 'fea_item_4225', 'fea_id','fea_small_bags', 'fea_total_Bags', 'fea_item_4770', 'fea_month', 
    'total_volumn_item', 'fea_total_Volume','fea_xlarge_bags' ]
lst_name = ['fea_type_organic', 'fea_large_bags', 'fea_item_4046', 'fea_year_', 'fea_item_4225', 'fea_id','fea_small_bags', 'fea_total_Bags', 'fea_item_4770', 'fea_month', 
    'total_volumn_item', 'fea_total_Volume','fea_xlarge_bags' ]

# %%
data_model_k_best_option1 = data_california[lst_k_best_option1]

# %% [markdown]
# ### 1.2. Check data

# %%
check = pre.data_preprocessing(data_model_k_best_option1, y="fea_average_price", task="regression")
# Out:
# --- check missing ---
#    OK: No missing
# --- check categorical data ---
#    OK: No categorical
# --- split train/test ---
#    OK: step skipped
# --- scaling ---
#    OK: step skipped

# %% [markdown]
# ### 1.3. Chia dữ liệu

# %%
dtf_train, dtf_test = pre.dtf_partitioning(data_model_k_best_option1, y="fea_average_price", test_size=0.3, shuffle=False)
# Out:
# X_train shape: (118, 13) | X_test shape: (51, 13)
# y_train mean: 1.65 | y_test mean: 1.77
# 14 features: ['fea_type_organic', 'fea_large_bags', 'fea_item_4046', 'fea_year_', 'fea_item_4225', 'fea_id', 'fea_small_bags', 'fea_total_Bags', 'fea_item_4770', 'fea_month', 'total_volumn_item', 'fea_total_Volume', 'fea_xlarge_bags']

# %% [markdown]
# ### 1.4. Thực hiện model

# %%
X = data_model_k_best_option1.drop(['fea_average_price'], axis=1)
y = data_model_k_best_option1['fea_average_price']

# %%
# Chia dữ liệu (Data splitting)
X_train, X_test, y_train, y_test = reg.train_test_split(X, y, random_state=42, test_size=0.3)

# %%
X_train = X_train[lst_name].values
y_train = y_train.values

# %%
X_test = X_test[lst_name].values
y_test = y_test.values

# %%
check = pre.data_preprocessing(data_model_k_best_option1, y="fea_average_price", task="regression")
# Out:
# --- check missing ---
#    OK: No missing
# --- check categorical data ---
#    OK: No categorical
# --- split train/test ---
#    OK: step skipped
# --- scaling ---
#    OK: step skipped

# %%
model_rf = reg.ExtraTreesRegressor()
model_rf = model_rf.fit(X_train, y_train)

# %%
# tinh RMSE, MAE, R^2
model = model_rf
print('Train Dataset RMSE: ', reg.mean_squared_error(y_true=y_train, y_pred=model.predict(X_train), squared=False))
print('Test Dataset RMSE: ', reg.mean_squared_error(y_true=y_test, y_pred=model.predict(X_test), squared=False))
print('Train Dataset R-square: ', model.score(X_train, y_train))
print('Test Dataset R-square: ', model.score(X_test, y_test))
# Out:
# Train Dataset RMSE:  2.4565631193126064e-15
# Test Dataset RMSE:  0.08865551308294364
# Train Dataset R-square:  1.0
# Test Dataset R-square:  0.8804122191257715

# %% [markdown]
# ### 1.5. Đánh giá

# %%
y_pred=model.predict(X_train)
predicted=model.predict(X_test)

# %%
reg.evaluate_regr_model(y_train, y_pred, figsize=(25,5))
# Out:
# R2 (explained variance): 1.0
# Mean Absolute Perc Error (Σ(|y-pred|/y)/n): 0.0
# Mean Absolute Error (Σ|y-pred|/n): 0
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)): 0
# Max Error: -0

# %%
reg.evaluate_regr_model(y_test, predicted, figsize=(25,5))
# Out:
# R2 (explained variance): 0.88
# Mean Absolute Perc Error (Σ(|y-pred|/y)/n): 0.04
# Mean Absolute Error (Σ|y-pred|/n): 0
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)): 0
# Max Error: 0

# %%
i = 1
print("True:", "{:,.0f}".format(y_test[i]), "--> Pred:", "{:,.0f}".format(predicted[i]))

exp.explainer_shap(model, lst_name, X_instance=X_test[i], X_train=None, task="regression", top=10)
# Out:
# True: 2 --> Pred: 2

# %% [markdown]
# ### Nhận xét:
# - R2 của tập train và test tưng ứng: 100% và 89% tương ứng cách khoảng 11% => cho nên có thể dẫn tới overfitting
# - MAE: Khoảng cách sai sót giữa test: 0.06
